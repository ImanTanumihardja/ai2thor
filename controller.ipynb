# %%
from ai2thor.controller import Controller
import ai2thor
import matplotlib.pyplot as plt
import numpy as np

# %%
controller = Controller(
    agentMode='vr',
    server_class=ai2thor.wsgi_server.WsgiServer,
    host="127.0.0.1",
    port=8200,
    start_unity=False,
)

# %%
controller.step("UnpausePhysicsAutoSim")

# %%
event = controller.step(action="RotateRight")
metadata = event.metadata
print(event, event.metadata.keys())

# %%
event = controller.step(action="RotateLeft")
metadata = event.metadata
print(event, event.metadata.keys())
# Out:
# <ai2thor.server.Event at 0x10dad1cc0
#     .metadata["lastAction"] = RotateLeft
#     .metadata["lastActionSuccess"] = True
#     .metadata["errorMessage"] = "
#     .metadata["actionReturn"] = None
# > dict_keys(['objects', 'isSceneAtRest', 'agent', 'heldObjectPose', 'arm', 'articulationArm', 'fov', 'cameraPosition', 'cameraRotation', 'worldRelativeCameraPosition', 'worldRelativeCameraRotation', 'agentPositionRelativeCameraPosition', 'agentRotationRelativeCameraRotation', 'cameraOrthSize', 'thirdPartyCameras', 'collided', 'collidedObjects', 'inventoryObjects', 'sceneName', 'lastAction', 'errorMessage', 'errorCode', 'lastActionSuccess', 'screenWidth', 'screenHeight', 'agentId', 'depthFormat', 'colors', 'flatSurfacesOnGrid', 'distances', 'normals', 'isOpenableGrid', 'segmentedObjectIds', 'objectIdsInBox', 'actionIntReturn', 'actionFloatReturn', 'actionStringsReturn', 'actionFloatsReturn', 'actionVector3sReturn', 'visibleRange', 'currentTime', 'sceneBounds', 'actionReturn'])

# %%
event = controller.step(action="MoveAhead")
metadata = event.metadata
print(event, event.metadata.keys())

# %%
# Visualize the AVP fov
avp_frame = event.third_party_camera_frames[0]
plt.imshow(avp_frame)
plt.axis('off')
plt.title("AVP FOV")
plt.show()

# %%
# Visualize the agent fov
agent_frame = event.frame
plt.imshow(agent_frame)
plt.axis('off')
plt.show()

# %%
event = controller.step(
    action="PickupObject",
    objectId="Apple|-00.47|+01.15|+00.48",
    forceAction=False,
    manualInteract=False
)
metadata = event.metadata
print(event, event.metadata.keys())

# %%
event = controller.step(action="Done")

# %%
# Stop controller
controller.stop()
